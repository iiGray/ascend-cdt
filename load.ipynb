# %%
import sys
sys.path.append("/data/jbb/ascend-cdt")
from mptools import read_pkl

dset = read_pkl("/data/jbb/long/deepseek/dataset_files/eval_DeepSeek-V2-Lite_32000.pkl")
dset
# Out:
# [2025-07-18 11:33:37,533] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /root/anaconda3/envs/bbj/bin/../lib/gcc/x86_64-conda-linux-gnu/11.2.0/../../../../x86_64-conda-linux-gnu/bin/ld: cannot find -laio: 没有那个文件或目录
# collect2: error: ld returned 1 exit status
# /root/anaconda3/envs/bbj/bin/../lib/gcc/x86_64-conda-linux-gnu/11.2.0/../../../../x86_64-conda-linux-gnu/bin/ld: cannot find -laio: 没有那个文件或目录
# collect2: error: ld returned 1 exit status
# [2025-07-18 11:33:39,958] [INFO] [logging.py:107:log_dist] [Rank -1] [TorchCheckpointEngine] Initialized with serialization = False

# %%
dset[0]
# Out:
# (0,
#  tensor([[   19,    17,    11,  ..., 27253,    11,   185]]),
#  tensor([[1, 1, 1,  ..., 1, 1, 1]]),
# ...

# %%
dset[1]
# Out:
# (0,
#  tensor([[  185,   185,   185,  ..., 27950,   768,   285]]),
#  tensor([[1, 1, 1,  ..., 1, 1, 1]]),
# ...
